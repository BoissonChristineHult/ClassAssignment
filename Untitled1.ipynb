# %%
number_one = 42
number_two = 28
sum_result = number_one + number_two
print(f"The sum is {sum_result}")
# Out:
# The sum is 70

# %%
first_name = "Christine"
surname = "Boisson"
full_name = first_name + " " + surname
print(full_name)
# Out:
# Christine Boisson

# %%
age = 28
print(f"{full_name} is {age} years old")
# Out:
# Christine Boisson is 28 years old
